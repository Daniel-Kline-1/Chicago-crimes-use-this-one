# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
import np as numpy



crime_csv_path = 'Chicago_crime.csv'
# Import the data into a Pandas DataFrame
crime_df = pd.read_csv(crime_csv_path)
crime_df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-dfaf69183944> in <module>
#       3 import matplotlib.pyplot as plt
#       4 from datetime import datetime
# ----> 5 import np as numpy
#       6
#       7
#
# ModuleNotFoundError: No module named 'np'

# %%
crime_df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c19cb1c43747> in <module>
# ----> 1 crime_df.columns
#
# NameError: name 'crime_df' is not defined

# %%
dff = pd.DataFrame({
    "ID":crime_df["ID"],
    "Year":crime_df["Year"],
    "Date":crime_df["Date"],
    "Primary Type":crime_df["Primary Type"],
    "Location Description":crime_df["Location Description"],
    "Latitude":crime_df["Latitude"],
    "Longitude":crime_df["Longitude"],
    "Location":crime_df["Location"]
})
dff.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-3c462fdd5077> in <module>
#       1 dff = pd.DataFrame({
# ----> 2     "ID":crime_df["ID"],
#       3     "Year":crime_df["Year"],
#       4     "Date":crime_df["Date"],
#       5     "Primary Type":crime_df["Primary Type"],
#
# NameError: name 'crime_df' is not defined

# %%
# look for missing values
dff.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fa029d6b2483> in <module>
#       1 # look for missing values
# ----> 2 dff.count()
#
# NameError: name 'dff' is not defined

# %%
# drop null rows
no_null_df = dff.dropna(how='any')
no_null_df.count()
# Out:
# ID                      1031678
# Year                    1031678
# Date                    1031678
# Primary Type            1031678
# Location Description    1031678
# Latitude                1031678
# Longitude               1031678
# Location                1031678
# dtype: int64

# %%
listss = no_null_df["Year"].unique()

# %%
#Remove 2019 because incomplete data
no_null_df = no_null_df[no_null_df['Year'] != 2019]
no_null_df.head()
# Out:
#         ID  Year             Date         Primary Type Location Description  \
# 0  1329893  2001  1/12/2001 17:30              BATTERY            RESIDENCE
# 1  1329967  2001  1/12/2001 19:30             BURGLARY            RESIDENCE
# 2  1346230  2001   1/23/2001 8:00                THEFT            RESIDENCE
# 3  1347551  2001  1/23/2001 20:29  MOTOR VEHICLE THEFT               STREET
# 4  1377882  2001   2/8/2001 21:00                THEFT               STREET
#
#     Latitude  Longitude                       Location
# 0  41.711629 -87.622141  (41.711628886, -87.622141173)
# 1  41.711651 -87.620852  (41.711651086, -87.620851734)
# 2  41.711856 -87.621648  (41.711856355, -87.621647891)
# 3  41.711841 -87.622652  (41.711840612, -87.622651588)
# 4  41.711840 -87.622578  (41.711840159, -87.622578343)

# %%
no_null_df.count()
# Out:
# ID                      1014567
# Year                    1014567
# Date                    1014567
# Primary Type            1014567
# Location Description    1014567
# Latitude                1014567
# Longitude               1014567
# Location                1014567
# dtype: int64

# %%
years_data = []
for year in list(range(2001,2018)):
    years_data.append(no_null_df.loc[dff['Year']== year,:])

# %%
years_data[0]
# Out:
#               ID  Year              Date         Primary Type  \
# 0        1329893  2001   1/12/2001 17:30              BATTERY
# 1        1329967  2001   1/12/2001 19:30             BURGLARY
# 2        1346230  2001    1/23/2001 8:00                THEFT
# 3        1347551  2001   1/23/2001 20:29  MOTOR VEHICLE THEFT
# 4        1377882  2001    2/8/2001 21:00                THEFT
# 5        1449754  2001   3/28/2001 21:04              BATTERY
# 6        1461783  2001   3/31/2001 16:55            NARCOTICS
# 7        1494449  2001   4/24/2001 18:00                THEFT
# 8        1496478  2001    4/23/2001 4:30                THEFT
# 9        1501958  2001    4/28/2001 0:01        OTHER OFFENSE
# 10       1570487  2001    6/8/2001 14:56              BATTERY
# 11       1589502  2001    6/20/2001 0:00  MOTOR VEHICLE THEFT
# 12       1641616  2001   7/19/2001 18:20              BATTERY
# 13       1641763  2001   7/11/2001 12:57              ASSAULT
# ...

# %%
# drop null rows
no_null = no_null_df.dropna(how='any')
no_null.count()
# Out:
# ID                      1014567
# Year                    1014567
# Date                    1014567
# Primary Type            1014567
# Location Description    1014567
# Latitude                1014567
# Longitude               1014567
# Location                1014567
# dtype: int64

# %%
#plot of the relatives amounts of each type of crime
plt.figure(figsize = (8,12))
no_null_df.groupby(no_null_df['Primary Type']).size().sort_values(ascending = False).plot(kind = 'barh')
plt.xlabel('Number of Crimes Committed')
plt.show()

# %%
theft = no_null_df[no_null_df["Primary Type"] == "THEFT"].groupby([no_null_df["Year"]])

#theft_x = theft["Year"].count()
#theft_y = theft["Primary Type"].count()

#plt.scatter(theft_x, theft_y, label = "Urban",  color=["coral"], edgecolor="black", alpha = 0.75, marker="o")
#plt.grid()


theft_y = theft["Primary Type"].count()
year = [2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010]
plt.scatter(year, theft_x, color='r')

plt.xlabel('Year')
plt.ylabel('Theft Count')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-d95223787d89> in <module>
# ----> 1 theft = no_null_df[no_null_df["Primary Type"] == "THEFT"].groupby([no_null_df["Year"]])
#       2
#       3 #theft_x = theft["Year"].count()
#       4 #theft_y = theft["Primary Type"].count()
#       5
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7630         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    7631                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 7632                        observed=observed, **kwargs)
#    7633
#    7634     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ...

# %%
no_null_df.plot(kind="scatter", x="Longitude", y="Latitude", alpha=1)

# %%
no_null_df.Date = pd.to_datetime(no_null_df.Date, format = '%m/%d/%Y %H:%M')
no_null_df.index = pd.DatetimeIndex(no_null_df.Date)

no_null_df['Primary Type'] = pd.Categorical(no_null_df['Primary Type'])
no_null_df['Location Description'] = pd.Categorical(no_null_df['Location Description'])

# %%
#make graph of crimes per year
plt.plot(figsize = (8,5))
no_null_df.groupby([no_null_df.index.year]).size().plot()
plt.title('Crime Over the Years')
plt.xlabel('Year')
plt.ylabel('Number of Crimes Acts')
plt.show()
plt.figure(figsize = (8,5))
#make graph of crimes per year
plt.plot(figsize = (8,5))
no_null_df.groupby([no_null_df.index.year]).size().plot.bar()
plt.title('Crime Over the Years')
plt.xlabel('Year')
plt.ylabel('Number of Crimes Acts')
plt.show()
plt.figure(figsize = (8,5))

# %%
#make graph of crimes per month

no_null_df.groupby([no_null_df.index.dayofweek]).size().plot.bar()
plt.title('Crime By Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Number of Crimes Acts')
plt.ylim(120000, 170000)
ax = plt.gca().set_xticklabels(\
    ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])

plt.show()

# %%
#make graph of crimes by day of week
plt.plot(figsize = (8,5))
no_null_df.groupby([no_null_df.index.month]).size().plot.bar()
plt.title('Crime Per Month')
plt.xlabel('Month')
plt.ylabel('Number of Crimes Acts')
ax = plt.gca().set_xticklabels(['January','February','March','April','May','June','July','August','September','October','November','December'])
plt.ylim(65000, 100000)
plt.show()

# %%
#graph of crimes per hour
no_null_df.groupby([no_null_df.index.hour]).size().plot.bar()
plt.title('Crime Per Hour')
plt.xlabel('Hour')
plt.ylabel('Number of Crimes Acts')
plt.show()
#graph of crimes per hour
no_null_df.groupby([no_null_df.index.hour]).size().plot()
plt.title('Crime Per Hour')
plt.xlabel('Hour')
plt.ylabel('Number of Crimes Acts')
plt.show()

# %%
crime = no_null_df['Date'].max()
crime

# %%
pivot = no_null_df[["Year", "Primary Type"]]
pivot

# %%
theft = pivot[pivot["Primary Type"] == "THEFT"].groupby([pivot["Year"]])

# %%
theft = no_null_df[no_null_df["Primary Type"] == "THEFT"].groupby([no_null_df["Year"]])


#theft_x = theft["Year"].count()
#theft_y = theft["Primary Type"].count()

#plt.scatter(theft_x, theft_y, label = "Urban",  color=["coral"], edgecolor="black", alpha = 0.75, marker="o")
#plt.grid()


theft_y = theft["Primary Type"].count()
year = [2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010]
plt.scatter(year, theft_x, color='r')

plt.xlabel('Year')
plt.ylabel('Theft Count')
plt.show()
#theft_x = theft["Year"].count()
#theft_y = theft["Primary Type"].count()

#plt.scatter(theft_x, theft_y, label = "Urban",  color=["coral"], edgecolor="black", alpha = 0.75, marker="o")
#plt.grid()


theft_y = theft["Primary Type"].count()
year = [2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010]
plt.scatter(year, theft_x, color='r')

plt.xlabel('Year')
plt.ylabel('Theft Count')
plt.show()

# %%
# Obtain the x and y coordinates for each of the three city types

theft = no_null_df[no_null_df["Primary Type"] == "THEFT"].groupby([no_null_df["Year"]])
battery = no_null_df[no_null_df["Primary Type"] == "BATTERY"].groupby([no_null_df["Year"]])
narcotic = no_null_df[no_null_df["Primary Type"] == "NARCOTICS"].groupby([no_null_df["Year"]])
damage = no_null_df[no_null_df["Primary Type"] == "CRIMINAL DAMAGE"].groupby([no_null_df["Year"]])
deceptive = no_null_df[no_null_df["Primary Type"] == "DECEPTIVE PRACTICE"].groupby([no_null_df["Year"]])

theft_x = theft["Year"].count()
theft_y = theft["Primary Type"].count()
urban_s = urban_type["driver_count"].mean()

rural_x = rural_type["ride_id"].count()
rural_y = rural_type["fare"].mean()
rural_s = rural_type["driver_count"].mean()

suburban_x = suburban_type["ride_id"].count()
suburban_y = suburban_type["fare"].mean()
suburban_s = suburban_type["driver_count"].mean()

# Build the scatter plots for each city types
plt.scatter(urban_x, urban_y, label = "Urban", s=urban_s * 10, color=["coral"], edgecolor="black", alpha = 0.75, marker="o")
plt.scatter(rural_x, rural_y, label = "Rural", s=rural_s * 10, color=["gold"], edgecolor="black", alpha = 0.75, marker="o")
plt.scatter(suburban_x,suburban_y, label = "Suburban", s=suburban_s  * 10, color=["skyblue"], edgecolor="black", alpha = 0.75, marker="o")
plt.grid()

# Incorporate the other graph properties
plt.xlabel("Total Number of Rides (Per City)")
plt.ylabel("Average Fare ($)")
plt.title("Pyber Data")


# Create a legend
legend = plt.legend(fontsize = 8, title= "City Type", loc="best") 

#Adjust legend
lgnd = plt.legend(frameon = True, edgecolor = 'black')
lgnd.legendHandles[0]._sizes = [75]
lgnd.legendHandles[1]._sizes = [75]
lgnd.legendHandles[2]._sizes = [75]
