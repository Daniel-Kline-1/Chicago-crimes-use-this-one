# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
import csv
from scipy import stats

# %%
path = "../Chicago_Crimedata.csv"
chicagocrime_df = pd.read_csv(path)
chicagocrime_df.head()
# Out:
#         ID Case Number             Date           Block IUCR  \
# 0  1329893     G025358  1/12/2001 17:30  0000X E 100 PL  420
# 1  1329967     G025724  1/12/2001 19:30  0000X E 100 PL  610
# 2  1346230     G047389   1/23/2001 8:00  0000X E 100 PL  820
# 3  1347551     G048475  1/23/2001 20:29  0000X E 100 PL  920
# 4  1377882     G082031   2/8/2001 21:00  0000X E 100 PL  820
#
#           Primary Type                     Description Location Description  \
# 0              BATTERY  AGGRAVATED:KNIFE/CUTTING INSTR            RESIDENCE
# 1             BURGLARY                  FORCIBLE ENTRY            RESIDENCE
# 2                THEFT                  $500 AND UNDER            RESIDENCE
# 3  MOTOR VEHICLE THEFT                 ATT: AUTOMOBILE               STREET
# 4                THEFT                  $500 AND UNDER               STREET
#
#    Arrest  Domestic  ...  Ward  Community Area  FBI Code  X Coordinate  \
# 0   False      True  ...   NaN             NaN       04B     1178432.0
# 1   False     False  ...   NaN             NaN         5     1178784.0
# 2   False     False  ...   NaN             NaN         6     1178566.0
# 3    True     False  ...   NaN             NaN         7     1178292.0
# 4   False     False  ...   NaN             NaN         6     1178312.0
#
#   Y Coordinate  Year       Updated On   Latitude  Longitude  \
# 0    1838311.0  2001  8/17/2015 15:03  41.711629 -87.622141
# 1    1838322.0  2001  8/17/2015 15:03  41.711651 -87.620852
# 2    1838395.0  2001  8/17/2015 15:03  41.711856 -87.621648
# 3    1838387.0  2001  8/17/2015 15:03  41.711841 -87.622652
# 4    1838387.0  2001  8/17/2015 15:03  41.711840 -87.622578
#
#                         Location
# 0  (41.711628886, -87.622141173)
# 1  (41.711651086, -87.620851734)
# 2  (41.711856355, -87.621647891)
# 3  (41.711840612, -87.622651588)
# 4  (41.711840159, -87.622578343)
#
# [5 rows x 22 columns]

# %%
chicagofiltered = chicagocrime_df.dropna()
chicagofiltered.head()
# Out:
#            ID Case Number              Date             Block  IUCR  \
# 97   10617651    HZ370496    7/30/2016 0:01  0000X E 100TH PL   460
# 98   11115190    JA467024  10/11/2017 11:52  0000X E 100TH PL   460
# 99    7282477    HR698720   12/20/2009 4:00  0000X E 100TH PL   810
# 100  10002332    HY191701   3/20/2015 11:12  0000X E 100TH PL  1822
# 101  10027995    HY217319   4/10/2015 17:00  0000X E 100TH PL   430
#
#     Primary Type                    Description Location Description  Arrest  \
# 97       BATTERY                         SIMPLE            RESIDENCE   False
# 98       BATTERY                         SIMPLE             SIDEWALK   False
# 99         THEFT                      OVER $500               STREET   False
# 100    NARCOTICS  MANU/DEL:CANNABIS OVER 10 GMS               STREET    True
# 101      BATTERY  AGGRAVATED: OTHER DANG WEAPON               STREET    True
#
#      Domestic  ...  Ward  Community Area  FBI Code  X Coordinate Y Coordinate  \
# 97       True  ...   9.0            49.0       08B     1178478.0    1838353.0
# 98      False  ...   9.0            49.0       08B     1178621.0    1838357.0
# 99      False  ...   9.0            49.0         6     1178529.0    1838354.0
# 100     False  ...   9.0            49.0        18     1178634.0    1838357.0
# 101      True  ...   9.0            49.0       04B     1178336.0    1838349.0
#
#      Year       Updated On   Latitude  Longitude  \
# 97   2016  2/10/2018 15:50  41.711743 -87.621971
# 98   2017  2/10/2018 15:50  41.711751 -87.621448
# 99   2009  2/10/2018 15:50  41.711745 -87.621785
# 100  2015  2/10/2018 15:50  41.711751 -87.621400
# 101  2015  2/10/2018 15:50  41.711735 -87.622492
#
#                           Location
# 97    (41.711743097, -87.62197144)
# 98    (41.71175083, -87.621447619)
# 99   (41.711744685, -87.621784635)
# 100  (41.711750536, -87.621400009)
# 101  (41.711735339, -87.622491598)
#
# [5 rows x 22 columns]

# %%
chicagocrime_df = pd.DataFrame({
    "ID":chicagofiltered["ID"],
    "Year":chicagofiltered["Year"],
    "Primary Type":chicagofiltered["Primary Type"],
    "Domestic":chicagofiltered["Domestic"],
    "Latitude":chicagofiltered["Latitude"],
    "Longitude":chicagofiltered["Longitude"],
    "Location":chicagofiltered["Location"]
})
chicagocrime_df.head()
# Out:
#            ID  Year Primary Type  Domestic   Latitude  Longitude  \
# 97   10617651  2016      BATTERY      True  41.711743 -87.621971
# 98   11115190  2017      BATTERY     False  41.711751 -87.621448
# 99    7282477  2009        THEFT     False  41.711745 -87.621785
# 100  10002332  2015    NARCOTICS     False  41.711751 -87.621400
# 101  10027995  2015      BATTERY      True  41.711735 -87.622492
#
#                           Location
# 97    (41.711743097, -87.62197144)
# 98    (41.71175083, -87.621447619)
# 99   (41.711744685, -87.621784635)
# 100  (41.711750536, -87.621400009)
# 101  (41.711735339, -87.622491598)

# %%
primary_group = chicagocrime_df.groupby("Primary Type")

crime_count = primary_group ["Year"].count().sort_values(ascending = False)
crime_count.head()

topfive = crime_count.head()
topfive
# Out:
# Primary Type
# THEFT                 263786
# BATTERY               149369
# NARCOTICS             108436
# CRIMINAL DAMAGE        80216
# DECEPTIVE PRACTICE     56329
# Name: Year, dtype: int64

# %%
by_year = chicagocrime_df.groupby(["Year"])["Primary Type"].count()
by_year
# Out:
# Year
# 2001      485
# 2002    49161
# 2003    67483
# 2004    66395
# 2005    63548
# 2006    63632
# 2007    62933
# 2008    60894
# 2009    55453
# 2010    54649
# 2011    53074
# 2012    52327
# 2013    48773
# 2014    44002
# 2015    41460
# 2016    45264
# 2017    47122
# 2018    48793
# 2019    17110
# Name: Primary Type, dtype: int64

# %%
#THEFT
theft_table = chicagocrime_df.loc[chicagocrime_df["Primary Type"]=="THEFT"]
theft_count = theft_table.groupby(["Year"])["Primary Type"].count()

#BATTERY
battery_table = chicagocrime_df.loc[chicagocrime_df["Primary Type"]=="BATTERY"]
battery_count = battery_table.groupby(["Year"])["Primary Type"].count()

# NARCOTICS
narcotics_table = chicagocrime_df.loc[chicagocrime_df["Primary Type"]=="NARCOTICS"]
narcotics_count = narcotics_table.groupby(["Year"])["Primary Type"].count()

# CRIMINAL DAMAGE 
criminal_damage_table = chicagocrime_df.loc[chicagocrime_df["Primary Type"]=="CRIMINAL DAMAGE"]
criminal_damage_count = criminal_damage_table.groupby(["Year"])["Primary Type"].count()
criminal_damage_count

# DECEPTIVE PRACTICE 
deceptive_practice_table = chicagocrime_df.loc[chicagocrime_df["Primary Type"]=="DECEPTIVE PRACTICE"]
deceptive_practice_count = deceptive_practice_table.groupby(["Year"])["Primary Type"].count()

crime_df = pd.DataFrame({"THEFT":theft_count,
                        "BATTERY":battery_count,
                        "NARCOTICS":narcotics_count,
                        "CRIMINAL DAMAGE":criminal_damage_count,
                        "DECEPTIVE PRACTICE":deceptive_practice_count})
crime_df.head()
# Out:
#       THEFT  BATTERY  NARCOTICS  CRIMINAL DAMAGE  DECEPTIVE PRACTICE
# Year
# 2001    148       27         31               13                  77
# 2002  13453     8462       5787             4296                2218
# 2003  17950    11246       9070             5893                2794
# 2004  17419    11165       8866             5731                2847
# 2005  15559    10580       8734             5968                2850

# %%
crime_df['Years'] = crime_df.index
crime_df.index
# Out:
# Int64Index([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019],
#            dtype='int64', name='Year')

# %%
year = crime_df.iloc[:,5]

# %%
#theft crime rate

theft_crime_rate = crime_df.iloc[:, 0]
tc_slope, tc_int, tc_r, tc_p, tc_std_err = stats.linregress(
   year, theft_crime_rate)
tc_fit = tc_slope * year + tc_int

#battery crime rate

battery_crime_rate = crime_df.iloc[:, 1]
bc_slope, bc_int, bc_r, bc_p, bc_std_err = stats.linregress(
   year, battery_crime_rate)
bc_fit = bc_slope * year + bc_int

#nacortics crime rate

nacortics_crime_rate = crime_df.iloc[:, 2]
nc_slope, nc_int, nc_r, nc_p, nc_std_err = stats.linregress(
   year, nacortics_crime_rate)
nc_fit = nc_slope * year + nc_int

#criminal damage crime rate

criminal_damage_crime_rate = crime_df.iloc[:, 3]
cdc_slope, cdc_int, cdc_r, cdc_p, cdc_std_err = stats.linregress(
   year, criminal_damage_crime_rate)
cdc_fit = cdc_slope * year + cdc_int

#deceptive practice crime rate

deceptive_practice_rate = crime_df.iloc[:, 4]
dpc_slope, dpc_int, dpc_r, dpc_p, dpc_std_err = stats.linregress(
   year, deceptive_practice_rate)
dpc_fit = dpc_slope * year + dpc_int

# %%
# Plot
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(5,figsize=(15,12), sharex=True)
fig.suptitle("Crime Rates Over Time", fontsize=16, fontweight="bold" , )




ax1.set_xlim(min(year), max(year))
ax1.plot(year, theft_crime_rate, linewidth=1, color="r", marker="o")
ax1.plot(year, tc_fit, "b--", linewidth=1)
ax1.set_ylabel("Theft Crime Rate")


ax2.plot(year, battery_crime_rate, linewidth=1, marker="o", color="r")
ax2.plot(year, bc_fit, "r--", linewidth=1)
ax2.set_ylabel("Battery Crime Rate")

ax3.plot(year, nacortics_crime_rate, linewidth=1, marker="o", color="g")
ax3.plot(year, nc_fit, "g--", linewidth=1)
ax3.set_ylabel("Narcotics Crime Rate")


ax4.plot(year, criminal_damage_crime_rate, linewidth=1, marker="o", color="c")
ax4.plot(year, cdc_fit, "c--", linewidth=1)
ax4.set_ylabel("Criminal Damage Rate")

ax5.plot(year, deceptive_practice_rate, linewidth=1, marker="o", color="y")
ax5.plot(year, dpc_fit, "y--", linewidth=3)
ax5.set_ylabel("Deceptive Practice Rate")
ax5.set_xlabel("Year")
# Out:
# Text(0.5, 0, 'Year')

# %%
# Print results for 2019
year = 2019
print("The theft crime rate in 2019 will be " +
      str(tc_slope * year + tc_int) + ".")
print("The battery crime rate in 2019 will be " + str(bc_slope * year + bc_int) + ".")
print("The nacortics crime rate in 2019 will be " +
      str(nc_slope * year + nc_int) + ".")
print("The criminal damage crime rate in 2019 will be " +
      str(cdc_slope * year + cdc_int) + ".")
print("The criminal damage crime rate in 2019 will be " +
      str(dpc_slope * year + dpc_int) + ".")
# Out:
# The theft crime rate in 2019 will be 13902.247368421053.
# The battery crime rate in 2019 will be 6552.989473684225.
# The nacortics crime rate in 2019 will be 3211.9000000000233.
# The criminal damage crime rate in 2019 will be 3340.2105263158155.
# The criminal damage crime rate in 2019 will be 3900.9526315789553.

# %%
# Print results for 2020

year = 2020
print("The theft crime rate in 2020 will be " +
      str(tc_slope * year + tc_int) + ".")
print("The battery crime rate in 2020 will be " + str(bc_slope * year + bc_int) + ".")
print("The nacortics crime rate in 2020 will be " +
      str(nc_slope * year + nc_int) + ".")
print("The criminal damage crime rate in 2020 will be " +
      str(cdc_slope * year + cdc_int) + ".")
print("The criminal damage crime rate in 2020 will be " +
      str(dpc_slope * year + dpc_int) + ".")


plt.savefig("Top 5 crime Prediction")
plt.show()
# Out:
# The theft crime rate in 2020 will be 13904.333333333334.
# The battery crime rate in 2020 will be 6407.596491228091.
# The nacortics crime rate in 2020 will be 2934.649122807081.
# The criminal damage crime rate in 2020 will be 3242.2456140351132.
# The criminal damage crime rate in 2020 will be 4004.9824561403657.
